# %% [markdown]
# Given two strings s and t of lengths m and n respectively, return the minimum window substring of s such that every character in t (including duplicates) is included in the window. If there is no such substring, return the empty string "".
#
# The testcases will be generated such that the answer is unique.
#
# A substring is a contiguous sequence of characters within the string.
#
#
#
# Example 1:
#
# Input: s = "ADOBECODEBANC", t = "ABC"
# Output: "BANC"
# Explanation: The minimum window substring "BANC" includes 'A', 'B', and 'C' from string t.
# Example 2:
#
# Input: s = "a", t = "a"
# Output: "a"
# Explanation: The entire string s is the minimum window.
# Example 3:
#
# Input: s = "a", t = "aa"
# Output: ""
# Explanation: Both 'a's from t must be included in the window.
# Since the largest window of s only has one 'a', return empty string.
#
#
# Constraints:
#
# m == s.length
# n == t.length
# 1 <= m, n <= 105
# s and t consist of uppercase and lowercase English letters.
#
#
# Follow up: Could you find an algorithm that runs in O(m + n) time?

# %%
class Solution:
    def minWindow(self, s: str, t: str) -> str:
        # Optimize last piece of codes
        # if t's length larger than s one, return ""
        if len(t)>len(s):
            return ""
        
        # we save the characters count of t string
        dict_t = {}
        for c in t:
            dict_t[c] = 1 if (c not in dict_t) else (dict_t[c]+1)
        
        # initialize the result as double length of s, so it will always get smaller if catched, otherwise we can decide to return empty string if it keeps double s length
        result = s+s
        subs = ""
        # This reached is important, it is the criterion for judging whether it includes all needs so far
        reached = 0
        for c in s:
            subs += c
            if c in dict_t:
                dict_t[c] -= 1
                if dict_t[c] == 0:
                    reached += 1
            if reached == len(dict_t): # it includes all needed characters now, find way to shrink left side
                #Always check the leftest element, if it makes the count value larger than 0 (eqauls to 1), it means that we have the anwser, then we subtract 1 for the reached, and compare whether it is shorter than previous one
                while True:
                    left = subs[0]
                    if left in dict_t:
                        dict_t[left] += 1
                        if dict_t[left]==1:
                            reached -= 1
                            if len(subs)<len(result):
                                result = subs
                            subs = subs[1:]
                            break
                    subs = subs[1:]
        return result if len(result)!=2*len(s) else ""
                
        
# This works, time complexity is much smaller
#         if len(t)>len(s):
#             return ""
        
#         dict_t = {} # record the characters in t
#         for c in t:
#             if c not in dict_t:
#                 dict_t[c] = 1
#             else:
#                 dict_t[c] += 1
        
#         t_dict_len = len(dict_t)
        
#         # results = []
#         result = s+s
#         reached_len = 0
        
#         subs = ""
#         for c in s:
#             subs += c
#             if c in dict_t:
#                 dict_t[c] -= 1
#                 if dict_t[c] == 0:
#                     reached_len +=1
#             if reached_len == t_dict_len:
#                 # print("it meets the good catch")
#                 # print(subs)
#                 i=0
#                 while i<len(subs):
#                     # print(subs[i])
#                     if subs[i] not in dict_t:
#                         subs = subs[:i]+subs[i+1:]
#                     else:
#                         if dict_t[subs[i]]+1<=0:
#                             dict_t[subs[i]] += 1
#                             subs = subs[:i]+subs[i+1:]
#                         else:
#                             if len(subs)<len(result):
#                                 result = subs
#                             # results.append(subs)
#                             dict_t[subs[i]] = 1
#                             subs = subs[:i]+subs[i+1:]
#                             reached_len -= 1
#                             # print("here we break the substr, the left substr is: "+subs)
#                             # print(dict_t)
#                             break
        
#         return result if result!=s+s else ""
        
        
#         # we need a sliding window
#         w_l = 0 # window left bar
#         w_r = 0 # window right bar
        
#         dict_subs = {s[0]:1}
#         subs = s[w_l:w_r]
#         while w_r<len(s):
            
            
            
#             # when right bar not reach to s end, we continue
#             w_r += 1
#             subs += s[w_r]
#             if s[w_r] not in dict_subs:
#                 dict_subs[s[w_r]] = 1
#             else:
#                 dict_subs[s[w_r]] += 1
#             # this is the sub string
#             # we can check whether the the substr include all the characters that t needs, but t is no matter to order, so, we need a t dict
            
        
        
        
        
# Old thinking, commented      
#         l = 0
#         r = 0
#         result = ""
#         #results = []
#         while r<len(s)+1:
#             substr = s[l:r]
#             meet = ""
#             for c in t:
#                 i=0
#                 while i<len(substr):
#                     if c==substr[i]:
#                         substr = substr[:i]+substr[i+1:]
#                         meet += c
#                         break
#                     else:
#                         i += 1
#             if meet==t:
#                 #substr includes t
                
#                 while s[l] not in t:
#                     l += 1
#                 #results.append(s[l:r])
#                 if len(result)==0:
#                     result = s[l:r]
#                 else:
#                     if len(s[l:r])<len(result):
#                         result = s[l:r]
#                 l += 1
#                 while l<len(s) and s[l] not in t:
#                     l += 1
#                 # while s[l] not in t:
#                 #     l += 1
#             else:
#                 r += 1
#             # if substr==s[l:r]: # means nothing in substr are in t
#         #return results
#         return result

# %%
class Solution:
    # it works, but the time complexity is exceed
    def minWindow(self, s: str, t: str) -> str:
        l = 0
        r = 0
        substr = s[l:r]
        substr_dict = {}
        if len(t)>len(s):
            return ""
        t_dict = {}
        for c in t:
            if c not in t_dict:
                t_dict[c] = 1
            else:
                t_dict[c] += 1
        print(t_dict)
        r_dict = t_dict
        while r<len(s):
            if s[r] in substr_dict:
                substr_dict[s[r]] = 1
            else:
                substr_dict[s[r]] += 1
            
            if s[r] in r_dict:
                r_dict[s[r]] -= 1
                if r_dict[s[r]]==0:
                    v
            else:
                pass

# %%
s = "ADOBECODEBANC"
t = "CBA"

# %%
s = "a"
t = "a"

# %%
s = "abcdef"
t = "abb"

# %%
s = "..."
t = "..."

# %%
s = "abc"
t = "ac"

# %%
Solution().minWindow(s,t)
# Out:
# 'abc'
